# %%
# !pip install pandas
# !pip install pymongo
# Out:
# Requirement already satisfied: pandas in c:\users\nagar\anaconda3\envs\davakhane\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nagar\anaconda3\envs\davakhane\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nagar\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nagar\anaconda3\envs\davakhane\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nagar\anaconda3\envs\davakhane\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\nagar\anaconda3\envs\davakhane\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pymongo in c:\users\nagar\appdata\roaming\python\python312\site-packages (4.12.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\nagar\appdata\roaming\python\python312\site-packages (from pymongo) (2.7.0)

# %%
import pandas as pd
import pymongo

df = pd.read_csv('dataset.csv')
df.head()
# Out:
#   Patient ID         Timestamp Age  Gender       Weight       Height  \
# 0         13  13-10-2025 16:50  40  Female  58.70038848  170.4094907
# 1          1  15-10-2025 07:10  77  Female  80.12666728  167.1793494
# 2          1  10-05-2025 21:50  77  Female  80.12666728  167.1793494
# 3          9  22-10-2025 01:20  71  Female  62.48597625  176.6769401
# 4          5  15-04-2025 04:20  44    Male  63.15993653  164.1298043
#
#            BMI   Heart Rate  BP Systolic BP Diastolic         SpO2  \
# 0  20.21405386  76.58680414  128.8826945  87.38316928  96.25592633
# 1  28.66895204  71.52149326  115.3069482  68.88272289  97.37895286
# 2  28.66895204  70.48309483  106.9585367  79.96893303   98.3274331
# 3  20.01809847  74.12814507   115.575141  71.37342474   98.3046963
# 4  23.44589316  67.57105683  139.1884179  76.36215884  98.45240715
#
#   Respiration Rate Body Temperature Blood Glucose Activity Level Sleep Pattern
# 0      16.16185502      99.07677324   124.6900112             48             1
# 1      16.33313168      98.93110379   108.9762947             55             1
# 2      16.78490009      98.36750288   98.38661462             44             1
# 3      14.77765795      98.24365978   82.21480161             52             1
# 4      16.64646459      99.12341595   97.65749733             43             0

# %%
collection.drop()  # Clears old bad data

# %%
data = df.to_dict(orient='records')

# %%
DB_NAME = "davakhane"
COLLECTION_NAME = "davakhane-Data"
CONNECTION_URL = "mongodb+srv://nagarajloni209_db_user:WoZCar3FzpuyNxPV@cluster0.5bytycx.mongodb.net/"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\nagar\appdata\roaming\python\python312\site-packages (4.12.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\nagar\appdata\roaming\python\python312\site-packages (from pymongo) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
rec = collection.insert_many(data)

# %%
import pandas as pd

input_file = "dataset.csv"
cleaned_file = "dataset_cleaned.csv"

with open(input_file, "r", encoding="utf-8") as infile, open(cleaned_file, "w", encoding="utf-8") as outfile:
    for line in infile:
        # Skip Git conflict markers and completely empty lines
        if not (line.startswith("<<<<<<<") or line.startswith("=======") or line.startswith(">>>>>>>") or line.strip() == ""):
            outfile.write(line)

# %%
df = pd.read_csv(cleaned_file)

df.columns = [
    "Patient ID","Timestamp","Age","Gender","Weight","Height","BMI",
    "Heart Rate","BP Systolic","BP Diastolic","SpO2","Respiration Rate",
    "Body Temperature","Blood Glucose","Activity Level","Sleep Pattern"
]

# Drop rows where Patient ID is not numeric
df = df[df["Patient ID"].apply(lambda x: str(x).isdigit())]

print(df.head())
# Out:
#   Patient ID         Timestamp Age  Gender       Weight       Height  \
# 0         13  13-10-2025 16:50  40  Female  58.70038848  170.4094907
# 1          1  15-10-2025 07:10  77  Female  80.12666728  167.1793494
# 2          1  10-05-2025 21:50  77  Female  80.12666728  167.1793494
# 3          9  22-10-2025 01:20  71  Female  62.48597625  176.6769401
# 4          5  15-04-2025 04:20  44    Male  63.15993653  164.1298043
#
#            BMI   Heart Rate  BP Systolic BP Diastolic         SpO2  \
# 0  20.21405386  76.58680414  128.8826945  87.38316928  96.25592633
# 1  28.66895204  71.52149326  115.3069482  68.88272289  97.37895286
# 2  28.66895204  70.48309483  106.9585367  79.96893303   98.3274331
# 3  20.01809847  74.12814507   115.575141  71.37342474   98.3046963
# 4  23.44589316  67.57105683  139.1884179  76.36215884  98.45240715
#
#   Respiration Rate Body Temperature Blood Glucose Activity Level Sleep Pattern
# 0      16.16185502      99.07677324   124.6900112             48             1
# 1      16.33313168      98.93110379   108.9762947             55             1
# 2      16.78490009      98.36750288   98.38661462             44             1
# 3      14.77765795      98.24365978   82.21480161             52             1
# 4      16.64646459      99.12341595   97.65749733             43             0

# %%
# Convert Timestamp to datetime
df["Timestamp"] = pd.to_datetime(df["Timestamp"], errors='coerce')

# Check for invalid dates
print(df[df["Timestamp"].isna()])
# Out:
# Empty DataFrame
# Columns: [Patient ID, Timestamp, Age, Gender, Weight, Height, BMI, Heart Rate, BP Systolic, BP Diastolic, SpO2, Respiration Rate, Body Temperature, Blood Glucose, Activity Level, Sleep Pattern]
# Index: []
# C:\Users\nagar\AppData\Local\Temp\ipykernel_16280\3887423985.py:2: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Timestamp"] = pd.to_datetime(df["Timestamp"], errors='coerce')

# %%
import pymongo

DB_NAME = "davakhane"
COLLECTION_NAME = "davakhane-Data"
CONNECTION_URL = "mongodb+srv://nagarajloni209_db_user:WoZCar3FzpuyNxPV@cluster0.5bytycx.mongodb.net/"

client = pymongo.MongoClient(CONNECTION_URL)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

# Drop old collection to remove bad records
collection.drop()

# Insert new clean data
data = df.to_dict(orient="records")
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('68bab0f16a05d21936e5e00d'), ObjectId('68bab0f16a05d21936e5e00e'), ObjectId('68bab0f16a05d21936e5e00f'), ObjectId('68bab0f16a05d21936e5e010'), ObjectId('68bab0f16a05d21936e5e011'), ObjectId('68bab0f16a05d21936e5e012'), ObjectId('68bab0f16a05d21936e5e013'), ObjectId('68bab0f16a05d21936e5e014'), ObjectId('68bab0f
a05d21936e5e04f'), ObjectId('68bab0f16a05d21936e5e050'), ObjectId('68bab0f16a05d21936e5e051'), ObjectId('68bab0f16a05d21936e5e052'), ObjectId('68bab0f16a05d21936e5e053'), ObjectId('68bab0f16a05d21936e5e054'), ObjectId('68bab0f16a05d21936e5e055'), ObjectId('68bab0f16a05d21936e5e056'), ObjectId('68bab0f16a05d21936e5e057'), ObjectId('68bab0f16a05d21936e5e058'), ObjectId('68bab0f16a05d21936e5e059'), ObjectId('68bab0f16a05d21936e5e05a'), ObjectId('68bab0f16a05d21936e5e05b'), ObjectId('68bab0f16a05d21936e5e05c'), ObjectId('68bab0f16a05d21936e5e05d'), ObjectId('68bab0f16a05d21936e5e05e'), ObjectId('68bab0f16a05d21936e5e05f'), ObjectId('68bab0f16a05d21936e5e060'), ObjectId('68bab0f16a05d21936e5e061'), ObjectId('68bab0f16a05d21936e5e062'), ObjectId('68bab0f16a05d21936e5e063'), ObjectId('68bab0f16a05d21936e5e064'), ObjectId('68bab0f16a05d21936e5e065'), ObjectId('68bab0f16a05d21936e5e066'), ObjectId('68bab0f16a05d21936e5e067'), ObjectId('68bab0f16a05d21936e5e068'), ObjectId('68bab0f16a05d21936e5e069'), ObjectId('68bab0f16a05d21936e5e06a'), ObjectId('68bab0f16a05d21936e5e06b'), ObjectId('68bab0f16a05d21936e5e06c'), ObjectId('68bab0f16a05d21936e5e06d'), ObjectId('68bab0f16a05d21936e5e06e'), ObjectId('68bab0f16a05d21936e5e06f'), ObjectId('68bab0f16a05d21936e5e070'), ObjectId('68bab0f16a05d21936e5e071'), ObjectId('68bab0f16a05d21936e5e072'), ObjectId('68bab0f16a05d21936e5e073'), ObjectId('68bab0f16a05d21936e5e074'), ObjectId('68bab0f16a05d21936e5 ...

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\nagar\appdata\roaming\python\python312\site-packages (4.12.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\nagar\appdata\roaming\python\python312\site-packages (from pymongo) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
#                         _id Patient ID           Timestamp Age  Gender  \
# 0  68bab0f16a05d21936e5e00d         13 2025-10-13 16:50:00  40  Female
# 1  68bab0f16a05d21936e5e00e          1 2025-10-15 07:10:00  77  Female
#
#         Weight       Height          BMI   Heart Rate  BP Systolic  \
# 0  58.70038848  170.4094907  20.21405386  76.58680414  128.8826945
# 1  80.12666728  167.1793494  28.66895204  71.52149326  115.3069482
#
#   BP Diastolic         SpO2 Respiration Rate Body Temperature Blood Glucose  \
# 0  87.38316928  96.25592633      16.16185502      99.07677324   124.6900112
# 1  68.88272289  97.37895286      16.33313168      98.93110379   108.9762947
#
#   Activity Level Sleep Pattern
# 0             48             1
# 1             55             1
